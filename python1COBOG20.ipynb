# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
print(3+5)
# Out:
# 8

# %%
print('AWS'+' re/Start')
# Out:
# AWS re/Start

# %%
print('AWS'+20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print('AWS'+20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
print(3+5)
# Out:
# 8

# %%
print('Hola'+'Mundo')
# Out:
# HolaMundo

# %%
print(type('Hola'))
print(type(288))
print(type(10.000009))
print(type(True))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
nombre = 'Nicolas'
edad = 28
notas = 6.8
casado = False

# %%
print(nombre)
# Out:
# Nicolas

# %%
print(edad)
# Out:
# 28

# %%
anno = '2026'
print(type(anno))
# Out:
# <class 'str'>

# %%
print(int(anno)-1)
# Out:
# 2025

# %%
nombre ='Interestelar'
anno = 2014
visto = True
salida = f'La pelicula {nombre} se esteno en el año {anno} vista: {visto}'
print(f'La pelicula {nombre} se esteno en el año {anno} vista: {visto}')
# Out:
# La pelicula Interestelar se esteno en el año 2014 vista: True

# %%
peliculas = [
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]

annos = [
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]

vistas = [
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

# %%
def peli_loop(nombre,anno,vista):
    for peli,ann,vista in zip(nombre,anno,vista):
        print(f'nombre:{peli} anno: {ann} vista:{vista}')

# %%
peli_loop(peliculas,annos,vistas)
# Out:
# nombre:The Shawshank Redemption anno: 1994 vista:True
# nombre:The Dark Knight anno: 2008 vista:False
# nombre:Inception anno: 2010 vista:True
# nombre:Pulp Fiction anno: 1994 vista:False
# nombre:The Matrix anno: 1999 vista:True
# nombre:Interstellar anno: 2014 vista:False
# nombre:Parasite anno: 2019 vista:True
# nombre:Gladiator anno: 2000 vista:False
# nombre:Titanic anno: 1997 vista:True
# nombre:The Lord of the Rings: The Fellowship of the Ring anno: 2001 vista:False
